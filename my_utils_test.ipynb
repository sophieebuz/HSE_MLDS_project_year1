# %%
import pandas as pd
X_train = pd.read_csv('C:/Users/uncle/Desktop/python/Project_1_HSE/clear_data_2015_2018.csv')
X_train
# Out:
#               date                                                url  \
# 0       2015-01-02         https://lenta.ru/news/2015/01/02/gorlovka/
# 1       2015-01-02          https://lenta.ru/news/2015/01/02/suspect/
# 2       2015-01-02          https://lenta.ru/news/2015/01/02/vnukovo/
# 3       2015-01-02          https://lenta.ru/news/2015/01/02/gerrard/
# 4       2015-01-02           https://lenta.ru/news/2015/01/02/dolgov/
# ...            ...                                                ...
# 210821  2017-11-27  https://lenta.ru/articles/2017/11/27/libya_dow...
# 210822  2018-07-19  https://lenta.ru/articles/2018/07/19/stalag_gu...
# 210823  2018-04-09         https://lenta.ru/articles/2018/04/09/iraq/
# 210824  2018-04-05  https://lenta.ru/articles/2018/04/05/unknown_s...
# 210825  2018-04-03        https://lenta.ru/articles/2018/04/03/ss100/
#
#                   topic          tags  \
# 0           Бывший СССР       Украина
# 1           Бывший СССР       Украина
# ...

# %%
import importlib 

import my_utils
importlib.reload(my_utils)
# Out:
# C:\Users\uncle\AppData\Local\Temp\ipykernel_34384\282882690.py:3: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# <module 'my_utils' from 'c:\\Users\\uncle\\Documents\\GitHub\\HSE_MLDS_project_year1\\my_utils.py'>

# %%
 my_utils.make_date_features(X_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34384\446017312.py in <cell line: 1>()
# ----> 1 my_utils.make_date_features(X_train)
#
# c:\Users\uncle\Documents\GitHub\HSE_MLDS_project_year1\my_utils.py in make_date_features(df)
#      31     df.loc[df['day_of_week'] >= 5, 'day_of_week'] = 0
#      32
# ---> 33     #df.drop('Unnamed: 0', axis=1, inplace=True)
#
# c:\Users\uncle\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# c:\Users\uncle\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...
